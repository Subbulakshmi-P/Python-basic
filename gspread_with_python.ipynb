# %% [markdown]
# <a href="https://colab.research.google.com/github/Subbulakshmi-P/Python-basic/blob/main/gspread_with_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

worksheet = gc.open_by_key('1mY8pNIV94ZYKZStSt1CNlwbJSv9GFiCy_3jXPKCb828').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
# [['Employee Name', 'EmpID', 'Gender', 'Marital Status', 'PayRate/Hour', 'Position', 'Department', 'Hire Date', 'TermReason', 'ManagerName', 'RecruitmentSource', 'Country', 'State', 'City', 'EmpSatisfaction'], ['Sreejith Sreenivasan', '1988299991', 'Male', 'Separated', '500', 'Vice President', 'Operations', '1/5/2015', 'N/A - still employed', 'Vaidya Vaibhav D.', 'LinkedIN', 'India', 'Gujarat', 'Surat', '4'], ['Darshana Pandit', '1599991009', 'Female', 'Single', '200', 'Executive', 'Production       ', '7/8/2013', 'N/A - still employed', 'Hadiya Hetal S.', 'Indeed', 'India', 'Gujarat', 'Vapi', '5'], ['T V Rao', '1504073368', 'Male', 'Married', '500', 'Vice President', 'HR', '8/15/2011', 'Another position', 'Vaidya Vaibhav D.', 'Naukri', 'India', 'Gujarat', 'Baroda', '5'], ['Nirav Modi', '1504073313', 'Male', 'Married', '210', 'Executive', 'Sales', '9/29/2014', 'N/A - still employed', 'Khalasi Apoorvakumar N.', 'Naukri', 'India', 'Gujarat', 'Rajkot', '5'], ['Chottan Turi', '1503072857'
# ...
